# %% [markdown]
# # Generate input images

# %% [markdown]
# ## Import libraries

# %%
import os
import cv2
import numpy as np
from PIL import Image
from pathlib import Path

# %% [markdown]
# ## Detect a main folder that will has all images folders

# %%
image_folder = Path('./images/input/') # Input images 
print("Image folder:", image_folder.resolve())
# Out:
# Image folder: /Volumes/TOSHIBA/Github Repositories/transformers/Swin Transformer/images/input

# %% [markdown]
# ## Create folders that have low quality image, noised and compressed image folders

# %%
def create_directories(image_folder):
    """Create necessary directories if they don't exist."""
    os.makedirs(os.path.join(image_folder, 'low_quality'), exist_ok=True)
    os.makedirs(os.path.join(image_folder, 'color_noise'), exist_ok=True)
    os.makedirs(os.path.join(image_folder, 'gray_noise'), exist_ok=True)
    os.makedirs(os.path.join(image_folder, 'color_jpeg'), exist_ok=True)
    os.makedirs(os.path.join(image_folder, 'gray_jpeg'), exist_ok=True)

# %% [markdown]
# ## Create a function that is downsized images with scales which are 2,3,4 and 8

# %%
def downsize_image(image, scale, name, image_folder):
    """Create downsized version of the image"""
    height, width = image.shape[:2]
    new_height = height // scale
    new_width = width // scale

    # Resize using INTER_AREA for downsizing (good quality)
    downsized = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_AREA)


    # Save downsized image
    output_path = f'{image_folder}/low_quality/{name}_{scale}x.png'
    cv2.imwrite(output_path, downsized)
    print(f"Saved: {output_path}")

# %% [markdown]
# ## Create a function that is noised images with noise level which are 15, 25 and 50

# %%
def add_gaussian_noise(image, noise_level):
    """Add Gaussian noise to image"""
    # Convert to float32 for noise addition
    image_float = image.astype(np.float32)

    # Generate Gaussian noise
    noise = np.random.normal(0, noise_level, image.shape).astype(np.float32)

    # Add noise and clip values to valid range
    noisy_image = np.clip(image_float + noise, 0, 255).astype(np.uint8)

    return noisy_image

# %%
def create_noisy_versions(image, name, image_folder):
    """Create noisy versions with different noise levels"""
    noise_levels = [15, 25, 50]

    # Convert BGR to RGB for processing
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    for noise_level in noise_levels:
        # Color noisy version
        color_noisy = add_gaussian_noise(image_rgb, noise_level)
        # Convert back to BGR for OpenCV saving
        color_noisy_bgr = cv2.cvtColor(color_noisy, cv2.COLOR_RGB2BGR)
        color_output_path = f'{image_folder}/color_noise/{name}_noise_{noise_level}.png'
        cv2.imwrite(color_output_path, color_noisy_bgr)
        print(f"Saved: {color_output_path}")

        # Grayscale noisy version
        gray_noisy = add_gaussian_noise(gray_image, noise_level)
        gray_output_path = f'{image_folder}/gray_noise/{name}_noise_{noise_level}.png'
        cv2.imwrite(gray_output_path, gray_noisy)
        print(f"Saved: {gray_output_path}")

# %% [markdown]
# ## Create a function that is compressed images with compression levels which are 10, 20, 30 and 40

# %%
def create_jpeg_compressed_versions(image, name, image_folder):
    """Create JPEG compressed versions with different quality levels"""
    compression_levels = [10, 20, 30, 40]

    # Convert BGR to RGB for PIL processing
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pil_image = Image.fromarray(image_rgb)

    # Convert to grayscale PIL image
    gray_pil = pil_image.convert('L')

    for quality in compression_levels:
        # Color JPEG compressed version
        color_output_path = f'{image_folder}/color_jpeg/{name}_color_jpeg_{quality}.png'
        pil_image.save(color_output_path, 'JPEG', quality=quality)
        print(f"Saved: {color_output_path}")

        # Grayscale JPEG compressed version
        gray_output_path = f'{image_folder}/gray_jpeg/{name}_gray_jpeg_{quality}.png'
        gray_pil.save(gray_output_path, 'JPEG', quality=quality)
        print(f"Saved: {gray_output_path}")

# %%
def process_image(image_path, image_folder):
  image = cv2.imread(image_path)
  if image is None:
    print(f"Error: Unable to read image from {image_path}")
    return

  name = os.path.splitext(os.path.basename(image_path))[0]
  print(f"Processing image: {name}")
  print(f"Original image size: {image.shape[1]}x{image.shape[0]}")

  create_directories(image_folder=image_folder)

  # 1. Create downsized versions (2x, 3x, 4x, 8x)
  print("\n=== Creating downsized versions ===")
  downsize_factors = [2, 3, 4, 8]
  for factor in downsize_factors:
      downsize_image(image, factor, name, image_folder)


  # 2. Create noisy versions (color and grayscale)
  print("\n=== Creating noisy versions ===")
  create_noisy_versions(image, name, image_folder)

  # 3. Create JPEG compressed versions
  print("\n=== Creating JPEG compressed versions ===")
  create_jpeg_compressed_versions(image, name, image_folder)

  print(f"\nProcessing complete! All versions saved for {name}")

# %%
image_original_dir = '/Volumes/TOSHIBA/Github Repositories/transformers/Swin Transformer/images/original'

for filename in os.listdir(image_original_dir):
    if filename.endswith('.jpeg'):
        img_path = os.path.join(image_original_dir, filename)
        try:
            #img = Image.open(img_path)
            print(f"Processing image: {filename}")
            process_image(img_path, image_folder)
        except Exception as e:
            print(f"Error processing image {filename}: {e}")
# Out:
# Processing image: audrey.jpeg
# Processing image: audrey
# Original image size: 417x600
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/audrey_2x.png
# Saved: images/input/low_quality/audrey_3x.png
# Saved: images/input/low_quality/audrey_4x.png
# Saved: images/input/low_quality/audrey_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/audrey_noise_15.png
# Saved: images/input/gray_noise/audrey_noise_15.png
# Saved: images/input/color_noise/audrey_noise_25.png
# Saved: images/input/gray_noise/audrey_noise_25.png
# Saved: images/input/color_noise/audrey_noise_50.png
# Saved: images/input/gray_noise/audrey_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/audrey_color_jpeg_10.png
# Saved: images/input/gray_jpeg/audrey_gray_jpeg_10.png
# Saved: images/input/color_jpeg/audrey_color_jpeg_20.png
# Saved: images/input/gray_jpeg/audrey_gray_jpeg_20.png
# Saved: images/input/color_jpeg/audrey_color_jpeg_30.png
# Saved: images/input/gray_jpeg/audrey_gray_jpeg_30.png
# Saved: images/input/color_jpeg/audrey_color_jpeg_40.png
# Saved: images/input/gray_jpeg/audrey_gray_jpeg_40.png
#
# Processing complete! All versions saved for audrey
# Processing image: beach.jpeg
# Processing image: beach
# Original image size: 736x920
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/beach_2x.png
# Saved: images/input/low_quality/beach_3x.png
# Saved: images/input/low_quality/beach_4x.png
# Saved: images/input/low_quality/beach_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/beach_noise_15.png
# Saved: images/input/gray_noise/beach_noise_15.png
# Saved: images/input/color_noise/beach_noise_25.png
# Saved: images/input/gray_noise/beach_noise_25.png
# Saved: images/input/color_noise/beach_noise_50.png
# Saved: images/input/gray_noise/beach_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/beach_color_jpeg_10.png
# Saved: images/input/gray_jpeg/beach_gray_jpeg_10.png
# Saved: images/input/color_jpeg/beach_color_jpeg_20.png
# Saved: images/input/gray_jpeg/beach_gray_jpeg_20.png
# Saved: images/input/color_jpeg/beach_color_jpeg_30.png
# Saved: images/input/gray_jpeg/beach_gray_jpeg_30.png
# Saved: images/input/color_jpeg/beach_color_jpeg_40.png
# Saved: images/input/gray_jpeg/beach_gray_jpeg_40.png
#
# Processing complete! All versions saved for beach
# Processing image: cat.jpeg
# Processing image: cat
# Original image size: 1200x1600
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/cat_2x.png
# Saved: images/input/low_quality/cat_3x.png
# Saved: images/input/low_quality/cat_4x.png
# Saved: images/input/low_quality/cat_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/cat_noise_15.png
# Saved: images/input/gray_noise/cat_noise_15.png
# Saved: images/input/color_noise/cat_noise_25.png
# Saved: images/input/gray_noise/cat_noise_25.png
# Saved: images/input/color_noise/cat_noise_50.png
# Saved: images/input/gray_noise/cat_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/cat_color_jpeg_10.png
# Saved: images/input/gray_jpeg/cat_gray_jpeg_10.png
# Saved: images/input/color_jpeg/cat_color_jpeg_20.png
# Saved: images/input/gray_jpeg/cat_gray_jpeg_20.png
# Saved: images/input/color_jpeg/cat_color_jpeg_30.png
# Saved: images/input/gray_jpeg/cat_gray_jpeg_30.png
# Saved: images/input/color_jpeg/cat_color_jpeg_40.png
# Saved: images/input/gray_jpeg/cat_gray_jpeg_40.png
#
# Processing complete! All versions saved for cat
# Processing image: dali.jpeg
# Processing image: dali
# Original image size: 438x795
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/dali_2x.png
# Saved: images/input/low_quality/dali_3x.png
# Saved: images/input/low_quality/dali_4x.png
# Saved: images/input/low_quality/dali_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/dali_noise_15.png
# Saved: images/input/gray_noise/dali_noise_15.png
# Saved: images/input/color_noise/dali_noise_25.png
# Saved: images/input/gray_noise/dali_noise_25.png
# Saved: images/input/color_noise/dali_noise_50.png
# Saved: images/input/gray_noise/dali_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/dali_color_jpeg_10.png
# Saved: images/input/gray_jpeg/dali_gray_jpeg_10.png
# Saved: images/input/color_jpeg/dali_color_jpeg_20.png
# Saved: images/input/gray_jpeg/dali_gray_jpeg_20.png
# Saved: images/input/color_jpeg/dali_color_jpeg_30.png
# Saved: images/input/gray_jpeg/dali_gray_jpeg_30.png
# Saved: images/input/color_jpeg/dali_color_jpeg_40.png
# Saved: images/input/gray_jpeg/dali_gray_jpeg_40.png
#
# Processing complete! All versions saved for dali
# Processing image: girl.jpeg
# Processing image: girl
# Original image size: 736x1104
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/girl_2x.png
# Saved: images/input/low_quality/girl_3x.png
# Saved: images/input/low_quality/girl_4x.png
# Saved: images/input/low_quality/girl_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/girl_noise_15.png
# Saved: images/input/gray_noise/girl_noise_15.png
# Saved: images/input/color_noise/girl_noise_25.png
# Saved: images/input/gray_noise/girl_noise_25.png
# Saved: images/input/color_noise/girl_noise_50.png
# Saved: images/input/gray_noise/girl_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/girl_color_jpeg_10.png
# Saved: images/input/gray_jpeg/girl_gray_jpeg_10.png
# Saved: images/input/color_jpeg/girl_color_jpeg_20.png
# Saved: images/input/gray_jpeg/girl_gray_jpeg_20.png
# Saved: images/input/color_jpeg/girl_color_jpeg_30.png
# Saved: images/input/gray_jpeg/girl_gray_jpeg_30.png
# Saved: images/input/color_jpeg/girl_color_jpeg_40.png
# Saved: images/input/gray_jpeg/girl_gray_jpeg_40.png
#
# Processing complete! All versions saved for girl
# Processing image: hand.jpeg
# Processing image: hand
# Original image size: 612x408
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/hand_2x.png
# Saved: images/input/low_quality/hand_3x.png
# Saved: images/input/low_quality/hand_4x.png
# Saved: images/input/low_quality/hand_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/hand_noise_15.png
# Saved: images/input/gray_noise/hand_noise_15.png
# Saved: images/input/color_noise/hand_noise_25.png
# Saved: images/input/gray_noise/hand_noise_25.png
# Saved: images/input/color_noise/hand_noise_50.png
# Saved: images/input/gray_noise/hand_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/hand_color_jpeg_10.png
# Saved: images/input/gray_jpeg/hand_gray_jpeg_10.png
# Saved: images/input/color_jpeg/hand_color_jpeg_20.png
# Saved: images/input/gray_jpeg/hand_gray_jpeg_20.png
# Saved: images/input/color_jpeg/hand_color_jpeg_30.png
# Saved: images/input/gray_jpeg/hand_gray_jpeg_30.png
# Saved: images/input/color_jpeg/hand_color_jpeg_40.png
# Saved: images/input/gray_jpeg/hand_gray_jpeg_40.png
#
# Processing complete! All versions saved for hand
# Processing image: hands.jpeg
# Processing image: hands
# Original image size: 2048x1152
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/hands_2x.png
# Saved: images/input/low_quality/hands_3x.png
# Saved: images/input/low_quality/hands_4x.png
# Saved: images/input/low_quality/hands_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/hands_noise_15.png
# Saved: images/input/gray_noise/hands_noise_15.png
# Saved: images/input/color_noise/hands_noise_25.png
# Saved: images/input/gray_noise/hands_noise_25.png
# Saved: images/input/color_noise/hands_noise_50.png
# Saved: images/input/gray_noise/hands_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/hands_color_jpeg_10.png
# Saved: images/input/gray_jpeg/hands_gray_jpeg_10.png
# Saved: images/input/color_jpeg/hands_color_jpeg_20.png
# Saved: images/input/gray_jpeg/hands_gray_jpeg_20.png
# Saved: images/input/color_jpeg/hands_color_jpeg_30.png
# Saved: images/input/gray_jpeg/hands_gray_jpeg_30.png
# Saved: images/input/color_jpeg/hands_color_jpeg_40.png
# Saved: images/input/gray_jpeg/hands_gray_jpeg_40.png
#
# Processing complete! All versions saved for hands
# Processing image: hands2.jpeg
# Processing image: hands2
# Original image size: 720x900
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/hands2_2x.png
# Saved: images/input/low_quality/hands2_3x.png
# Saved: images/input/low_quality/hands2_4x.png
# Saved: images/input/low_quality/hands2_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/hands2_noise_15.png
# Saved: images/input/gray_noise/hands2_noise_15.png
# Saved: images/input/color_noise/hands2_noise_25.png
# Saved: images/input/gray_noise/hands2_noise_25.png
# Saved: images/input/color_noise/hands2_noise_50.png
# Saved: images/input/gray_noise/hands2_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/hands2_color_jpeg_10.png
# Saved: images/input/gray_jpeg/hands2_gray_jpeg_10.png
# Saved: images/input/color_jpeg/hands2_color_jpeg_20.png
# Saved: images/input/gray_jpeg/hands2_gray_jpeg_20.png
# Saved: images/input/color_jpeg/hands2_color_jpeg_30.png
# Saved: images/input/gray_jpeg/hands2_gray_jpeg_30.png
# Saved: images/input/color_jpeg/hands2_color_jpeg_40.png
# Saved: images/input/gray_jpeg/hands2_gray_jpeg_40.png
#
# Processing complete! All versions saved for hands2
# Processing image: happiness.jpeg
# Processing image: happiness
# Original image size: 736x1104
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/happiness_2x.png
# Saved: images/input/low_quality/happiness_3x.png
# Saved: images/input/low_quality/happiness_4x.png
# Saved: images/input/low_quality/happiness_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/happiness_noise_15.png
# Saved: images/input/gray_noise/happiness_noise_15.png
# Saved: images/input/color_noise/happiness_noise_25.png
# Saved: images/input/gray_noise/happiness_noise_25.png
# Saved: images/input/color_noise/happiness_noise_50.png
# Saved: images/input/gray_noise/happiness_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/happiness_color_jpeg_10.png
# Saved: images/input/gray_jpeg/happiness_gray_jpeg_10.png
# Saved: images/input/color_jpeg/happiness_color_jpeg_20.png
# Saved: images/input/gray_jpeg/happiness_gray_jpeg_20.png
# Saved: images/input/color_jpeg/happiness_color_jpeg_30.png
# Saved: images/input/gray_jpeg/happiness_gray_jpeg_30.png
# Saved: images/input/color_jpeg/happiness_color_jpeg_40.png
# Saved: images/input/gray_jpeg/happiness_gray_jpeg_40.png
#
# Processing complete! All versions saved for happiness
# Processing image: howls.jpeg
# Processing image: howls
# Original image size: 564x1002
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/howls_2x.png
# Saved: images/input/low_quality/howls_3x.png
# Saved: images/input/low_quality/howls_4x.png
# Saved: images/input/low_quality/howls_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/howls_noise_15.png
# Saved: images/input/gray_noise/howls_noise_15.png
# Saved: images/input/color_noise/howls_noise_25.png
# Saved: images/input/gray_noise/howls_noise_25.png
# Saved: images/input/color_noise/howls_noise_50.png
# Saved: images/input/gray_noise/howls_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/howls_color_jpeg_10.png
# Saved: images/input/gray_jpeg/howls_gray_jpeg_10.png
# Saved: images/input/color_jpeg/howls_color_jpeg_20.png
# Saved: images/input/gray_jpeg/howls_gray_jpeg_20.png
# Saved: images/input/color_jpeg/howls_color_jpeg_30.png
# Saved: images/input/gray_jpeg/howls_gray_jpeg_30.png
# Saved: images/input/color_jpeg/howls_color_jpeg_40.png
# Saved: images/input/gray_jpeg/howls_gray_jpeg_40.png
#
# Processing complete! All versions saved for howls
# Processing image: kid.jpeg
# Processing image: kid
# Original image size: 599x900
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/kid_2x.png
# Saved: images/input/low_quality/kid_3x.png
# Saved: images/input/low_quality/kid_4x.png
# Saved: images/input/low_quality/kid_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/kid_noise_15.png
# Saved: images/input/gray_noise/kid_noise_15.png
# Saved: images/input/color_noise/kid_noise_25.png
# Saved: images/input/gray_noise/kid_noise_25.png
# Saved: images/input/color_noise/kid_noise_50.png
# Saved: images/input/gray_noise/kid_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/kid_color_jpeg_10.png
# Saved: images/input/gray_jpeg/kid_gray_jpeg_10.png
# Saved: images/input/color_jpeg/kid_color_jpeg_20.png
# Saved: images/input/gray_jpeg/kid_gray_jpeg_20.png
# Saved: images/input/color_jpeg/kid_color_jpeg_30.png
# Saved: images/input/gray_jpeg/kid_gray_jpeg_30.png
# Saved: images/input/color_jpeg/kid_color_jpeg_40.png
# Saved: images/input/gray_jpeg/kid_gray_jpeg_40.png
#
# Processing complete! All versions saved for kid
# Processing image: messi.jpeg
# Processing image: messi
# Original image size: 474x711
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/messi_2x.png
# Saved: images/input/low_quality/messi_3x.png
# Saved: images/input/low_quality/messi_4x.png
# Saved: images/input/low_quality/messi_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/messi_noise_15.png
# Saved: images/input/gray_noise/messi_noise_15.png
# Saved: images/input/color_noise/messi_noise_25.png
# Saved: images/input/gray_noise/messi_noise_25.png
# Saved: images/input/color_noise/messi_noise_50.png
# Saved: images/input/gray_noise/messi_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/messi_color_jpeg_10.png
# Saved: images/input/gray_jpeg/messi_gray_jpeg_10.png
# Saved: images/input/color_jpeg/messi_color_jpeg_20.png
# Saved: images/input/gray_jpeg/messi_gray_jpeg_20.png
# Saved: images/input/color_jpeg/messi_color_jpeg_30.png
# Saved: images/input/gray_jpeg/messi_gray_jpeg_30.png
# Saved: images/input/color_jpeg/messi_color_jpeg_40.png
# Saved: images/input/gray_jpeg/messi_gray_jpeg_40.png
#
# Processing complete! All versions saved for messi
# Processing image: movie_poster.jpeg
# Processing image: movie_poster
# Original image size: 736x1115
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/movie_poster_2x.png
# Saved: images/input/low_quality/movie_poster_3x.png
# Saved: images/input/low_quality/movie_poster_4x.png
# Saved: images/input/low_quality/movie_poster_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/movie_poster_noise_15.png
# Saved: images/input/gray_noise/movie_poster_noise_15.png
# Saved: images/input/color_noise/movie_poster_noise_25.png
# Saved: images/input/gray_noise/movie_poster_noise_25.png
# Saved: images/input/color_noise/movie_poster_noise_50.png
# Saved: images/input/gray_noise/movie_poster_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/movie_poster_color_jpeg_10.png
# Saved: images/input/gray_jpeg/movie_poster_gray_jpeg_10.png
# Saved: images/input/color_jpeg/movie_poster_color_jpeg_20.png
# Saved: images/input/gray_jpeg/movie_poster_gray_jpeg_20.png
# Saved: images/input/color_jpeg/movie_poster_color_jpeg_30.png
# Saved: images/input/gray_jpeg/movie_poster_gray_jpeg_30.png
# Saved: images/input/color_jpeg/movie_poster_color_jpeg_40.png
# Saved: images/input/gray_jpeg/movie_poster_gray_jpeg_40.png
#
# Processing complete! All versions saved for movie_poster
# Processing image: mri_head.jpeg
# Processing image: mri_head
# Original image size: 340x340
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/mri_head_2x.png
# Saved: images/input/low_quality/mri_head_3x.png
# Saved: images/input/low_quality/mri_head_4x.png
# Saved: images/input/low_quality/mri_head_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/mri_head_noise_15.png
# Saved: images/input/gray_noise/mri_head_noise_15.png
# Saved: images/input/color_noise/mri_head_noise_25.png
# Saved: images/input/gray_noise/mri_head_noise_25.png
# Saved: images/input/color_noise/mri_head_noise_50.png
# Saved: images/input/gray_noise/mri_head_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/mri_head_color_jpeg_10.png
# Saved: images/input/gray_jpeg/mri_head_gray_jpeg_10.png
# Saved: images/input/color_jpeg/mri_head_color_jpeg_20.png
# Saved: images/input/gray_jpeg/mri_head_gray_jpeg_20.png
# Saved: images/input/color_jpeg/mri_head_color_jpeg_30.png
# Saved: images/input/gray_jpeg/mri_head_gray_jpeg_30.png
# Saved: images/input/color_jpeg/mri_head_color_jpeg_40.png
# Saved: images/input/gray_jpeg/mri_head_gray_jpeg_40.png
#
# Processing complete! All versions saved for mri_head
# Processing image: office.jpeg
# Processing image: office
# Original image size: 736x981
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/office_2x.png
# Saved: images/input/low_quality/office_3x.png
# Saved: images/input/low_quality/office_4x.png
# Saved: images/input/low_quality/office_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/office_noise_15.png
# Saved: images/input/gray_noise/office_noise_15.png
# Saved: images/input/color_noise/office_noise_25.png
# Saved: images/input/gray_noise/office_noise_25.png
# Saved: images/input/color_noise/office_noise_50.png
# Saved: images/input/gray_noise/office_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/office_color_jpeg_10.png
# Saved: images/input/gray_jpeg/office_gray_jpeg_10.png
# Saved: images/input/color_jpeg/office_color_jpeg_20.png
# Saved: images/input/gray_jpeg/office_gray_jpeg_20.png
# Saved: images/input/color_jpeg/office_color_jpeg_30.png
# Saved: images/input/gray_jpeg/office_gray_jpeg_30.png
# Saved: images/input/color_jpeg/office_color_jpeg_40.png
# Saved: images/input/gray_jpeg/office_gray_jpeg_40.png
#
# Processing complete! All versions saved for office
# Processing image: oil_rig.jpeg
# Processing image: oil_rig
# Original image size: 736x1231
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/oil_rig_2x.png
# Saved: images/input/low_quality/oil_rig_3x.png
# Saved: images/input/low_quality/oil_rig_4x.png
# Saved: images/input/low_quality/oil_rig_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/oil_rig_noise_15.png
# Saved: images/input/gray_noise/oil_rig_noise_15.png
# Saved: images/input/color_noise/oil_rig_noise_25.png
# Saved: images/input/gray_noise/oil_rig_noise_25.png
# Saved: images/input/color_noise/oil_rig_noise_50.png
# Saved: images/input/gray_noise/oil_rig_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/oil_rig_color_jpeg_10.png
# Saved: images/input/gray_jpeg/oil_rig_gray_jpeg_10.png
# Saved: images/input/color_jpeg/oil_rig_color_jpeg_20.png
# Saved: images/input/gray_jpeg/oil_rig_gray_jpeg_20.png
# Saved: images/input/color_jpeg/oil_rig_color_jpeg_30.png
# Saved: images/input/gray_jpeg/oil_rig_gray_jpeg_30.png
# Saved: images/input/color_jpeg/oil_rig_color_jpeg_40.png
# Saved: images/input/gray_jpeg/oil_rig_gray_jpeg_40.png
#
# Processing complete! All versions saved for oil_rig
# Processing image: painting.jpeg
# Processing image: painting
# Original image size: 659x865
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/painting_2x.png
# Saved: images/input/low_quality/painting_3x.png
# Saved: images/input/low_quality/painting_4x.png
# Saved: images/input/low_quality/painting_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/painting_noise_15.png
# Saved: images/input/gray_noise/painting_noise_15.png
# Saved: images/input/color_noise/painting_noise_25.png
# Saved: images/input/gray_noise/painting_noise_25.png
# Saved: images/input/color_noise/painting_noise_50.png
# Saved: images/input/gray_noise/painting_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/painting_color_jpeg_10.png
# Saved: images/input/gray_jpeg/painting_gray_jpeg_10.png
# Saved: images/input/color_jpeg/painting_color_jpeg_20.png
# Saved: images/input/gray_jpeg/painting_gray_jpeg_20.png
# Saved: images/input/color_jpeg/painting_color_jpeg_30.png
# Saved: images/input/gray_jpeg/painting_gray_jpeg_30.png
# Saved: images/input/color_jpeg/painting_color_jpeg_40.png
# Saved: images/input/gray_jpeg/painting_gray_jpeg_40.png
#
# Processing complete! All versions saved for painting
# Processing image: painting2.jpeg
# Processing image: painting2
# Original image size: 559x800
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/painting2_2x.png
# Saved: images/input/low_quality/painting2_3x.png
# Saved: images/input/low_quality/painting2_4x.png
# Saved: images/input/low_quality/painting2_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/painting2_noise_15.png
# Saved: images/input/gray_noise/painting2_noise_15.png
# Saved: images/input/color_noise/painting2_noise_25.png
# Saved: images/input/gray_noise/painting2_noise_25.png
# Saved: images/input/color_noise/painting2_noise_50.png
# Saved: images/input/gray_noise/painting2_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/painting2_color_jpeg_10.png
# Saved: images/input/gray_jpeg/painting2_gray_jpeg_10.png
# Saved: images/input/color_jpeg/painting2_color_jpeg_20.png
# Saved: images/input/gray_jpeg/painting2_gray_jpeg_20.png
# Saved: images/input/color_jpeg/painting2_color_jpeg_30.png
# Saved: images/input/gray_jpeg/painting2_gray_jpeg_30.png
# Saved: images/input/color_jpeg/painting2_color_jpeg_40.png
# Saved: images/input/gray_jpeg/painting2_gray_jpeg_40.png
#
# Processing complete! All versions saved for painting2
# Processing image: spirited_away.jpeg
# Processing image: spirited_away
# Original image size: 736x1308
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/spirited_away_2x.png
# Saved: images/input/low_quality/spirited_away_3x.png
# Saved: images/input/low_quality/spirited_away_4x.png
# Saved: images/input/low_quality/spirited_away_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/spirited_away_noise_15.png
# Saved: images/input/gray_noise/spirited_away_noise_15.png
# Saved: images/input/color_noise/spirited_away_noise_25.png
# Saved: images/input/gray_noise/spirited_away_noise_25.png
# Saved: images/input/color_noise/spirited_away_noise_50.png
# Saved: images/input/gray_noise/spirited_away_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/spirited_away_color_jpeg_10.png
# Saved: images/input/gray_jpeg/spirited_away_gray_jpeg_10.png
# Saved: images/input/color_jpeg/spirited_away_color_jpeg_20.png
# Saved: images/input/gray_jpeg/spirited_away_gray_jpeg_20.png
# Saved: images/input/color_jpeg/spirited_away_color_jpeg_30.png
# Saved: images/input/gray_jpeg/spirited_away_gray_jpeg_30.png
# Saved: images/input/color_jpeg/spirited_away_color_jpeg_40.png
# Saved: images/input/gray_jpeg/spirited_away_gray_jpeg_40.png
#
# Processing complete! All versions saved for spirited_away
# Processing image: starry_night.jpeg
# Processing image: starry_night
# Original image size: 735x490
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/starry_night_2x.png
# Saved: images/input/low_quality/starry_night_3x.png
# Saved: images/input/low_quality/starry_night_4x.png
# Saved: images/input/low_quality/starry_night_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/starry_night_noise_15.png
# Saved: images/input/gray_noise/starry_night_noise_15.png
# Saved: images/input/color_noise/starry_night_noise_25.png
# Saved: images/input/gray_noise/starry_night_noise_25.png
# Saved: images/input/color_noise/starry_night_noise_50.png
# Saved: images/input/gray_noise/starry_night_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/starry_night_color_jpeg_10.png
# Saved: images/input/gray_jpeg/starry_night_gray_jpeg_10.png
# Saved: images/input/color_jpeg/starry_night_color_jpeg_20.png
# Saved: images/input/gray_jpeg/starry_night_gray_jpeg_20.png
# Saved: images/input/color_jpeg/starry_night_color_jpeg_30.png
# Saved: images/input/gray_jpeg/starry_night_gray_jpeg_30.png
# Saved: images/input/color_jpeg/starry_night_color_jpeg_40.png
# Saved: images/input/gray_jpeg/starry_night_gray_jpeg_40.png
#
# Processing complete! All versions saved for starry_night
# Processing image: street.jpeg
# Processing image: street
# Original image size: 736x736
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/street_2x.png
# Saved: images/input/low_quality/street_3x.png
# Saved: images/input/low_quality/street_4x.png
# Saved: images/input/low_quality/street_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/street_noise_15.png
# Saved: images/input/gray_noise/street_noise_15.png
# Saved: images/input/color_noise/street_noise_25.png
# Saved: images/input/gray_noise/street_noise_25.png
# Saved: images/input/color_noise/street_noise_50.png
# Saved: images/input/gray_noise/street_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/street_color_jpeg_10.png
# Saved: images/input/gray_jpeg/street_gray_jpeg_10.png
# Saved: images/input/color_jpeg/street_color_jpeg_20.png
# Saved: images/input/gray_jpeg/street_gray_jpeg_20.png
# Saved: images/input/color_jpeg/street_color_jpeg_30.png
# Saved: images/input/gray_jpeg/street_gray_jpeg_30.png
# Saved: images/input/color_jpeg/street_color_jpeg_40.png
# Saved: images/input/gray_jpeg/street_gray_jpeg_40.png
#
# Processing complete! All versions saved for street
# Processing image: sunrise.jpeg
# Processing image: sunrise
# Original image size: 736x1138
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/sunrise_2x.png
# Saved: images/input/low_quality/sunrise_3x.png
# Saved: images/input/low_quality/sunrise_4x.png
# Saved: images/input/low_quality/sunrise_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/sunrise_noise_15.png
# Saved: images/input/gray_noise/sunrise_noise_15.png
# Saved: images/input/color_noise/sunrise_noise_25.png
# Saved: images/input/gray_noise/sunrise_noise_25.png
# Saved: images/input/color_noise/sunrise_noise_50.png
# Saved: images/input/gray_noise/sunrise_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/sunrise_color_jpeg_10.png
# Saved: images/input/gray_jpeg/sunrise_gray_jpeg_10.png
# Saved: images/input/color_jpeg/sunrise_color_jpeg_20.png
# Saved: images/input/gray_jpeg/sunrise_gray_jpeg_20.png
# Saved: images/input/color_jpeg/sunrise_color_jpeg_30.png
# Saved: images/input/gray_jpeg/sunrise_gray_jpeg_30.png
# Saved: images/input/color_jpeg/sunrise_color_jpeg_40.png
# Saved: images/input/gray_jpeg/sunrise_gray_jpeg_40.png
#
# Processing complete! All versions saved for sunrise
# Processing image: sunset.jpeg
# Processing image: sunset
# Original image size: 736x977
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/sunset_2x.png
# Saved: images/input/low_quality/sunset_3x.png
# Saved: images/input/low_quality/sunset_4x.png
# Saved: images/input/low_quality/sunset_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/sunset_noise_15.png
# Saved: images/input/gray_noise/sunset_noise_15.png
# Saved: images/input/color_noise/sunset_noise_25.png
# Saved: images/input/gray_noise/sunset_noise_25.png
# Saved: images/input/color_noise/sunset_noise_50.png
# Saved: images/input/gray_noise/sunset_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/sunset_color_jpeg_10.png
# Saved: images/input/gray_jpeg/sunset_gray_jpeg_10.png
# Saved: images/input/color_jpeg/sunset_color_jpeg_20.png
# Saved: images/input/gray_jpeg/sunset_gray_jpeg_20.png
# Saved: images/input/color_jpeg/sunset_color_jpeg_30.png
# Saved: images/input/gray_jpeg/sunset_gray_jpeg_30.png
# Saved: images/input/color_jpeg/sunset_color_jpeg_40.png
# Saved: images/input/gray_jpeg/sunset_gray_jpeg_40.png
#
# Processing complete! All versions saved for sunset
# Processing image: sunset2.jpeg
# Processing image: sunset2
# Original image size: 735x980
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/sunset2_2x.png
# Saved: images/input/low_quality/sunset2_3x.png
# Saved: images/input/low_quality/sunset2_4x.png
# Saved: images/input/low_quality/sunset2_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/sunset2_noise_15.png
# Saved: images/input/gray_noise/sunset2_noise_15.png
# Saved: images/input/color_noise/sunset2_noise_25.png
# Saved: images/input/gray_noise/sunset2_noise_25.png
# Saved: images/input/color_noise/sunset2_noise_50.png
# Saved: images/input/gray_noise/sunset2_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/sunset2_color_jpeg_10.png
# Saved: images/input/gray_jpeg/sunset2_gray_jpeg_10.png
# Saved: images/input/color_jpeg/sunset2_color_jpeg_20.png
# Saved: images/input/gray_jpeg/sunset2_gray_jpeg_20.png
# Saved: images/input/color_jpeg/sunset2_color_jpeg_30.png
# Saved: images/input/gray_jpeg/sunset2_gray_jpeg_30.png
# Saved: images/input/color_jpeg/sunset2_color_jpeg_40.png
# Saved: images/input/gray_jpeg/sunset2_gray_jpeg_40.png
#
# Processing complete! All versions saved for sunset2
# Processing image: totoro.jpeg
# Processing image: totoro
# Original image size: 736x1308
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/totoro_2x.png
# Saved: images/input/low_quality/totoro_3x.png
# Saved: images/input/low_quality/totoro_4x.png
# Saved: images/input/low_quality/totoro_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/totoro_noise_15.png
# Saved: images/input/gray_noise/totoro_noise_15.png
# Saved: images/input/color_noise/totoro_noise_25.png
# Saved: images/input/gray_noise/totoro_noise_25.png
# Saved: images/input/color_noise/totoro_noise_50.png
# Saved: images/input/gray_noise/totoro_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/totoro_color_jpeg_10.png
# Saved: images/input/gray_jpeg/totoro_gray_jpeg_10.png
# Saved: images/input/color_jpeg/totoro_color_jpeg_20.png
# Saved: images/input/gray_jpeg/totoro_gray_jpeg_20.png
# Saved: images/input/color_jpeg/totoro_color_jpeg_30.png
# Saved: images/input/gray_jpeg/totoro_gray_jpeg_30.png
# Saved: images/input/color_jpeg/totoro_color_jpeg_40.png
# Saved: images/input/gray_jpeg/totoro_gray_jpeg_40.png
#
# Processing complete! All versions saved for totoro
# Processing image: tram.jpeg
# Processing image: tram
# Original image size: 736x1104
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/tram_2x.png
# Saved: images/input/low_quality/tram_3x.png
# Saved: images/input/low_quality/tram_4x.png
# Saved: images/input/low_quality/tram_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/tram_noise_15.png
# Saved: images/input/gray_noise/tram_noise_15.png
# Saved: images/input/color_noise/tram_noise_25.png
# Saved: images/input/gray_noise/tram_noise_25.png
# Saved: images/input/color_noise/tram_noise_50.png
# Saved: images/input/gray_noise/tram_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/tram_color_jpeg_10.png
# Saved: images/input/gray_jpeg/tram_gray_jpeg_10.png
# Saved: images/input/color_jpeg/tram_color_jpeg_20.png
# Saved: images/input/gray_jpeg/tram_gray_jpeg_20.png
# Saved: images/input/color_jpeg/tram_color_jpeg_30.png
# Saved: images/input/gray_jpeg/tram_gray_jpeg_30.png
# Saved: images/input/color_jpeg/tram_color_jpeg_40.png
# Saved: images/input/gray_jpeg/tram_gray_jpeg_40.png
#
# Processing complete! All versions saved for tram
# Processing image: tree.jpeg
# Processing image: tree
# Original image size: 736x981
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/tree_2x.png
# Saved: images/input/low_quality/tree_3x.png
# Saved: images/input/low_quality/tree_4x.png
# Saved: images/input/low_quality/tree_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/tree_noise_15.png
# Saved: images/input/gray_noise/tree_noise_15.png
# Saved: images/input/color_noise/tree_noise_25.png
# Saved: images/input/gray_noise/tree_noise_25.png
# Saved: images/input/color_noise/tree_noise_50.png
# Saved: images/input/gray_noise/tree_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/tree_color_jpeg_10.png
# Saved: images/input/gray_jpeg/tree_gray_jpeg_10.png
# Saved: images/input/color_jpeg/tree_color_jpeg_20.png
# Saved: images/input/gray_jpeg/tree_gray_jpeg_20.png
# Saved: images/input/color_jpeg/tree_color_jpeg_30.png
# Saved: images/input/gray_jpeg/tree_gray_jpeg_30.png
# Saved: images/input/color_jpeg/tree_color_jpeg_40.png
# Saved: images/input/gray_jpeg/tree_gray_jpeg_40.png
#
# Processing complete! All versions saved for tree
# Processing image: valley.jpeg
# Processing image: valley
# Original image size: 700x875
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/valley_2x.png
# Saved: images/input/low_quality/valley_3x.png
# Saved: images/input/low_quality/valley_4x.png
# Saved: images/input/low_quality/valley_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/valley_noise_15.png
# Saved: images/input/gray_noise/valley_noise_15.png
# Saved: images/input/color_noise/valley_noise_25.png
# Saved: images/input/gray_noise/valley_noise_25.png
# Saved: images/input/color_noise/valley_noise_50.png
# Saved: images/input/gray_noise/valley_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/valley_color_jpeg_10.png
# Saved: images/input/gray_jpeg/valley_gray_jpeg_10.png
# Saved: images/input/color_jpeg/valley_color_jpeg_20.png
# Saved: images/input/gray_jpeg/valley_gray_jpeg_20.png
# Saved: images/input/color_jpeg/valley_color_jpeg_30.png
# Saved: images/input/gray_jpeg/valley_gray_jpeg_30.png
# Saved: images/input/color_jpeg/valley_color_jpeg_40.png
# Saved: images/input/gray_jpeg/valley_gray_jpeg_40.png
#
# Processing complete! All versions saved for valley
# Processing image: wall_text.jpeg
# Processing image: wall_text
# Original image size: 675x1200
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/wall_text_2x.png
# Saved: images/input/low_quality/wall_text_3x.png
# Saved: images/input/low_quality/wall_text_4x.png
# Saved: images/input/low_quality/wall_text_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/wall_text_noise_15.png
# Saved: images/input/gray_noise/wall_text_noise_15.png
# Saved: images/input/color_noise/wall_text_noise_25.png
# Saved: images/input/gray_noise/wall_text_noise_25.png
# Saved: images/input/color_noise/wall_text_noise_50.png
# Saved: images/input/gray_noise/wall_text_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/wall_text_color_jpeg_10.png
# Saved: images/input/gray_jpeg/wall_text_gray_jpeg_10.png
# Saved: images/input/color_jpeg/wall_text_color_jpeg_20.png
# Saved: images/input/gray_jpeg/wall_text_gray_jpeg_20.png
# Saved: images/input/color_jpeg/wall_text_color_jpeg_30.png
# Saved: images/input/gray_jpeg/wall_text_gray_jpeg_30.png
# Saved: images/input/color_jpeg/wall_text_color_jpeg_40.png
# Saved: images/input/gray_jpeg/wall_text_gray_jpeg_40.png
#
# Processing complete! All versions saved for wall_text
# Processing image: words.jpeg
# Processing image: words
# Original image size: 1278x870
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/words_2x.png
# Saved: images/input/low_quality/words_3x.png
# Saved: images/input/low_quality/words_4x.png
# Saved: images/input/low_quality/words_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/words_noise_15.png
# Saved: images/input/gray_noise/words_noise_15.png
# Saved: images/input/color_noise/words_noise_25.png
# Saved: images/input/gray_noise/words_noise_25.png
# Saved: images/input/color_noise/words_noise_50.png
# Saved: images/input/gray_noise/words_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/words_color_jpeg_10.png
# Saved: images/input/gray_jpeg/words_gray_jpeg_10.png
# Saved: images/input/color_jpeg/words_color_jpeg_20.png
# Saved: images/input/gray_jpeg/words_gray_jpeg_20.png
# Saved: images/input/color_jpeg/words_color_jpeg_30.png
# Saved: images/input/gray_jpeg/words_gray_jpeg_30.png
# Saved: images/input/color_jpeg/words_color_jpeg_40.png
# Saved: images/input/gray_jpeg/words_gray_jpeg_40.png
#
# Processing complete! All versions saved for words
# Processing image: workspace.jpeg
# Processing image: workspace
# Original image size: 736x1309
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/workspace_2x.png
# Saved: images/input/low_quality/workspace_3x.png
# Saved: images/input/low_quality/workspace_4x.png
# Saved: images/input/low_quality/workspace_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/workspace_noise_15.png
# Saved: images/input/gray_noise/workspace_noise_15.png
# Saved: images/input/color_noise/workspace_noise_25.png
# Saved: images/input/gray_noise/workspace_noise_25.png
# Saved: images/input/color_noise/workspace_noise_50.png
# Saved: images/input/gray_noise/workspace_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/workspace_color_jpeg_10.png
# Saved: images/input/gray_jpeg/workspace_gray_jpeg_10.png
# Saved: images/input/color_jpeg/workspace_color_jpeg_20.png
# Saved: images/input/gray_jpeg/workspace_gray_jpeg_20.png
# Saved: images/input/color_jpeg/workspace_color_jpeg_30.png
# Saved: images/input/gray_jpeg/workspace_gray_jpeg_30.png
# Saved: images/input/color_jpeg/workspace_color_jpeg_40.png
# Saved: images/input/gray_jpeg/workspace_gray_jpeg_40.png
#
# Processing complete! All versions saved for workspace
# Processing image: x_ray_hand.jpeg
# Processing image: x_ray_hand
# Original image size: 736x1159
#
# === Creating downsized versions ===
# Saved: images/input/low_quality/x_ray_hand_2x.png
# Saved: images/input/low_quality/x_ray_hand_3x.png
# Saved: images/input/low_quality/x_ray_hand_4x.png
# Saved: images/input/low_quality/x_ray_hand_8x.png
#
# === Creating noisy versions ===
# Saved: images/input/color_noise/x_ray_hand_noise_15.png
# Saved: images/input/gray_noise/x_ray_hand_noise_15.png
# Saved: images/input/color_noise/x_ray_hand_noise_25.png
# Saved: images/input/gray_noise/x_ray_hand_noise_25.png
# Saved: images/input/color_noise/x_ray_hand_noise_50.png
# Saved: images/input/gray_noise/x_ray_hand_noise_50.png
#
# === Creating JPEG compressed versions ===
# Saved: images/input/color_jpeg/x_ray_hand_color_jpeg_10.png
# Saved: images/input/gray_jpeg/x_ray_hand_gray_jpeg_10.png
# Saved: images/input/color_jpeg/x_ray_hand_color_jpeg_20.png
# Saved: images/input/gray_jpeg/x_ray_hand_gray_jpeg_20.png
# Saved: images/input/color_jpeg/x_ray_hand_color_jpeg_30.png
# Saved: images/input/gray_jpeg/x_ray_hand_gray_jpeg_30.png
# Saved: images/input/color_jpeg/x_ray_hand_color_jpeg_40.png
# Saved: images/input/gray_jpeg/x_ray_hand_gray_jpeg_40.png
#
# Processing complete! All versions saved for x_ray_hand

# %% [markdown]
# # Ploting all images

# %%
import glob
import matplotlib.pyplot as plt

# %%
def load_image_safe(path):
    """Safely load an image and handle errors"""
    try:
        if os.path.exists(path):
            # Try with OpenCV first
            img = cv2.imread(path)
            if img is not None:
                return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            # Fallback to PIL
            with Image.open(path) as pil_img:
                return np.array(pil_img)
        return None
    except Exception as e:
        print(f"Error loading {path}: {e}")
        return None
